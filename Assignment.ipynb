# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_df = pd.read_excel("C:/Users/deepak.kapri/Downloads/Data Science boot camp/Credit Card Data.xlsx",
                        sheet_name = 'Customer Details')

#sheet_name = none can be used to read all tabs under one dataframe

# %%
customer_df.head(10)
# Out:
#    No Customer  Age       City   Product    Limit Company        Segment
# 0   1       A1   47  BANGALORE      Gold  1500000      C1  Self Employed
# 1   2       A2   56   CALCUTTA    Silver   300000      C2   Salaried_MNC
# 2   3       A3   30     COCHIN  Platimum   540000      C3   Salaried_Pvt
# 3   4       A4   22     BOMBAY  Platimum   840084      C4           Govt
# 4   5       A5   59  BANGALORE  Platimum   420084      C5  Normal Salary
# 5   6       A6   51      DELHI    Silver   600000      C6  Self Employed
# 6   7       A7   18     COCHIN    Silver   600006      C7   Salaried_MNC
# 7   8       A8   50      PATNA    Silver   600000      C8   Salaried_Pvt
# 8   9       A9   63    CHENNAI    Silver   600000      C9           Govt
# 9  10      A10   25   CALCUTTA      Gold   500000     C10  Normal Salary

# %%
customer_df.shape
# Out:
# (100, 8)

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        100 non-null    int64
#  1   Customer  100 non-null    object
#  2   Age       100 non-null    int64
#  3   City      100 non-null    object
#  4   Product   100 non-null    object
#  5   Limit     100 non-null    int64
#  6   Company   100 non-null    object
#  7   Segment   100 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 6.4+ KB

# %%
print(customer_df['Customer'].unique)
# Out:
# <bound method Series.unique of 0       A1
# 1       A2
# 2       A3
# 3       A4
# 4       A5
#       ...
# 95     A96
# 96     A97
# 97     A98
# 98     A99
# 99    A100
# Name: Customer, Length: 100, dtype: object>

# %%
print(customer_df['Customer'].value_counts())
# Out:
# A1      1
# A64     1
# A74     1
# A73     1
# A72     1
#        ..
# A31     1
# A30     1
# A29     1
# A28     1
# A100    1
# Name: Customer, Length: 100, dtype: int64

# %%
spend_df = pd.read_excel("C:/Users/deepak.kapri/Downloads/Data Science boot camp/Credit Card Data.xlsx",
                          sheet_name = 'Spend')

# %%
spend_df
# Out:
#       Sl No: Customer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  344054.980813
# 1          2       A1 2004-01-03       PETRO     935.495203
# 2          3       A1 2004-01-15     CLOTHES    8687.895474
# 3          4       A1 2004-01-25        FOOD     341.159711
# 4          5       A1 2005-01-17      CAMERA    3406.639477
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET   41831.671089
# 1496    1497      A68 2006-03-25  BUS TICKET   22218.200843
# 1497    1498      A69 2006-03-31  BUS TICKET   10004.907926
# 1498    1499      A70 2006-03-23  BUS TICKET   31630.825400
# 1499    1500      A71 2006-03-24  BUS TICKET   33048.374357
#
# [1500 rows x 5 columns]

# %%
spend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   datetime64[ns]
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 58.7+ KB

# %%
spend_df.isna().any()
# Out:
# Sl No:      False
# Customer    False
# Month       False
# Type        False
# Amount      False
# dtype: bool

# %%
merge_df = pd.merge(customer_df,spend_df,on = 'Customer',how= 'inner')

# %%
merge_df.head(10)
# Out:
#    No Customer  Age       City Product    Limit Company        Segment  \
# 0   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 1   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 2   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 3   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 4   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 5   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 6   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 7   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 8   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
# 9   1       A1   47  BANGALORE    Gold  1500000      C1  Self Employed
#
#    Sl No:      Month          Type        Amount
# 0       1 2004-01-12     JEWELLERY  3.440550e+05
# 1       2 2004-01-03         PETRO  9.354952e+02
# ...

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Age       1500 non-null   int64
#  3   City      1500 non-null   object
#  4   Product   1500 non-null   object
#  5   Limit     1500 non-null   int64
#  6   Company   1500 non-null   object
#  7   Segment   1500 non-null   object
#  8   Sl No:    1500 non-null   int64
#  9   Month     1500 non-null   datetime64[ns]
#  10  Type      1500 non-null   object
#  11  Amount    1500 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 152.3+ KB

# %%
merge_df.shape
# Out:
# (1500, 12)

# %%
merge_df.isna().any()
# Out:
# No          False
# Customer    False
# Age         False
# City        False
# Product     False
# Limit       False
# Company     False
# Segment     False
# Sl No:      False
# Month       False
# Type        False
# Amount      False
# dtype: bool

# %%
repayment_df = pd.read_excel("C:/Users/deepak.kapri/Downloads/Data Science boot camp/Credit Card Data.xlsx",
                          sheet_name = 'Repayment')

# %%
repayment_df
# Out:
#      SL No: Customer      Month        Amount
# 0         1       A1 2006-05-15  2.308473e+05
# 1         2       A1 2005-08-27  1.835124e+03
# 2         3       A1 2004-03-07  4.858701e+03
# 3         4       A1 2005-03-01  1.360527e+06
# 4         5       A1 2004-02-14  1.902322e+05
# ..      ...      ...        ...           ...
# 802     803      A95 2004-01-31  2.819752e+05
# 803     804      A96 2004-01-26  5.061918e+04
# 804     805      A97 2004-02-02  5.186467e+03
# 805     806      A98 2004-02-05  1.274603e+04
# 806     807      A99 2004-02-04  1.081372e+05
#
# [807 rows x 4 columns]

# %%
repayment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SL No:    807 non-null    int64
#  1   Customer  807 non-null    object
#  2   Month     803 non-null    datetime64[ns]
#  3   Amount    807 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 25.3+ KB

# %%
repayment_df.isnull().any()
# Out:
# SL No:      False
# Customer    False
# Month        True
# Amount      False
# dtype: bool

# %%
repayment_df.isnull().sum()
# Out:
# SL No:      0
# Customer    0
# Month       4
# Amount      0
# dtype: int64

# %%
#Finding missing data from Month Table
repayment_df[repayment_df['Month'].isnull()]
# Out:
#      SL No: Customer Month         Amount
# 274     275      A29   NaT  139343.954497
# 299     300      A30   NaT   75520.695090
# 418     419      A40   NaT    4203.395579
# 789     790       A9   NaT   20150.636740

# %%
repayment_df['Month'].mode()
# Out:
# 0   2006-03-27
# Name: Month, dtype: datetime64[ns]

# %%
Mode_Month = pd.to_datetime('2006-03-27')

# %%
#replacing missing date with mode. 
repayment_df['Month']= repayment_df['Month'].fillna(Mode_Month)

# %%
repayment_df[repayment_df['Month'].isnull()]
# Out:
# Empty DataFrame
# Columns: [SL No:, Customer, Month, Amount]
# Index: []

# %%
credit_card = pd.merge(merge_df,repayment_df,on='Customer',how='inner')

# %%
credit_card
# Out:
#         No Customer  Age        City   Product    Limit Company  \
# 0        1       A1   47   BANGALORE      Gold  1500000      C1
# 1        1       A1   47   BANGALORE      Gold  1500000      C1
# 2        1       A1   47   BANGALORE      Gold  1500000      C1
# 3        1       A1   47   BANGALORE      Gold  1500000      C1
# 4        1       A1   47   BANGALORE      Gold  1500000      C1
# ...    ...      ...  ...         ...       ...      ...     ...
# 18785   96      A96   54     CHENNAI    Silver   100000     C19
# 18786   97      A97   75  TRIVANDRUM  Platimum    30000     C20
# 18787   98      A98   29    CALCUTTA  Platimum    30000     C21
# 18788   99      A99   59    CALCUTTA  Platimum   120000     C22
# 18789  100     A100   55      COCHIN    Silver   100000      C5
#
#              Segment  Sl No:    Month_x        Type       Amount_x  SL No:  \
# 0      Self Employed       1 2004-01-12   JEWELLERY  344054.980813       1
# ...

# %%
credit_card.isnull().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# Sl No:      0
# Month_x     0
# Type        0
# Amount_x    0
# SL No:      0
# Month_y     0
# Amount_y    0
# dtype: int64

# %% [markdown]
# # 2) Make the following substitution:

# %% [markdown]
# a. Age of credit card customer can't be less than 18. In case age is less than 18, replace
# it with mean of age

# %%
credit_card[credit_card['Age']<18]
# Out:
#        No Customer  Age     City   Product    Limit Company        Segment  \
# 13695  47      A47   16  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13696  47      A47   16  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13697  47      A47   16  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13698  47      A47   16  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13699  47      A47   16  CHENNAI  Platimum  1380000      C9  Normal Salary
# ...    ..      ...  ...      ...       ...      ...     ...            ...
# 18753  70      A70   16   BOMBAY  Platimum   420000     C32  Self Employed
# 18754  70      A70   16   BOMBAY  Platimum   420000     C32  Self Employed
# 18755  70      A70   16   BOMBAY  Platimum   420000     C32  Self Employed
# 18756  70      A70   16   BOMBAY  Platimum   420000     C32  Self Employed
# 18783  94      A94   14   COCHIN      Gold   500000     C17           Govt
#
# ...

# %%
Age_mean= credit_card['Age'].mean()

# %%
print(round(Age_mean,1))
# Out:
# 48.8

# %%
credit_card.loc[credit_card["Age"]<18,"Age"]=48.8

# %%
credit_card[credit_card['Age']==48.8]
# Out:
#        No Customer   Age     City   Product    Limit Company        Segment  \
# 13695  47      A47  48.8  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13696  47      A47  48.8  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13697  47      A47  48.8  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13698  47      A47  48.8  CHENNAI  Platimum  1380000      C9  Normal Salary
# 13699  47      A47  48.8  CHENNAI  Platimum  1380000      C9  Normal Salary
# ...    ..      ...   ...      ...       ...      ...     ...            ...
# 18753  70      A70  48.8   BOMBAY  Platimum   420000     C32  Self Employed
# 18754  70      A70  48.8   BOMBAY  Platimum   420000     C32  Self Employed
# 18755  70      A70  48.8   BOMBAY  Platimum   420000     C32  Self Employed
# 18756  70      A70  48.8   BOMBAY  Platimum   420000     C32  Self Employed
# 18783  94      A94  48.8   COCHIN      Gold   500000     C17           Govt
#
# ...

# %% [markdown]
# # a. How many unique customers are there?

# %%
credit_card['Customer'].nunique()
# Out:
# 100

# %% [markdown]
# # b. How many spend categories are there?

# %%
credit_card['Type'].value_counts()
# Out:
# PETRO           2488
# CAMERA          2121
# FOOD            1987
# AIR TICKET      1778
# TRAIN TICKET    1705
# SHOPPING        1407
# JEWELLERY       1249
# BUS TICKET      1181
# CLOTHES         1096
# RENTAL          1008
# MOVIE TICKET     968
# BIKE             616
# AUTO             503
# CAR              354
# SANDALS          329
# Name: Type, dtype: int64

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18790 entries, 0 to 18789
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        18790 non-null  int64
#  1   Customer  18790 non-null  object
#  2   Age       18790 non-null  float64
#  3   City      18790 non-null  object
#  4   Product   18790 non-null  object
#  5   Limit     18790 non-null  int64
#  6   Company   18790 non-null  object
#  7   Segment   18790 non-null  object
#  8   Sl No:    18790 non-null  int64
#  9   Month_x   18790 non-null  datetime64[ns]
#  10  Type      18790 non-null  object
#  11  Amount_x  18790 non-null  float64
#  12  SL No:    18790 non-null  int64
#  13  Month_y   18790 non-null  datetime64[ns]
#  14  Amount_y  18790 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(6)
# memory usage: 2.3+ MB

# %% [markdown]
# # c. Which category has the highest average spend?

# %%
credit_card.groupby(['Segment'])['Amount_y'].mean()
# Out:
# Segment
# Govt             101768.425892
# Normal Salary    118358.633045
# Salaried_MNC      83412.983985
# Salaried_Pvt      87762.674172
# Self Employed    100201.319153
# Name: Amount_y, dtype: float64

# %% [markdown]
# # d. What is the average monthly spent by product categories?

# %%
credit_card.groupby(['Product','Month_y'])['Amount_y'].mean()
# Out:
# Product  Month_y
# Gold     2004-01-24    138919.906930
#          2004-01-25     27009.296632
#          2004-01-27    247653.888376
#          2004-01-30     16266.849008
#          2004-01-31    265927.023315
#                            ...
# Silver   2006-12-14      2368.570492
#          2006-12-15      2052.209512
#          2006-12-16     18320.923230
#          2006-12-18       447.980861
#          2006-12-28     22737.578895
# Name: Amount_y, Length: 633, dtype: float64

# %% [markdown]
# # e. Which customers are reaching 90% or more of their spending limit?

# %% [markdown]
# # f. Which city has the maximum number of spenders, each month? Is there a need to run campaigns in specific cities?

# %%
credit_card.groupby(['City'])['Customer'].nunique()
# Out:
# City
# BANGALORE     19
# BOMBAY        14
# CALCUTTA      18
# CHENNAI        8
# COCHIN        20
# DELHI          7
# PATNA          7
# TRIVANDRUM     7
# Name: Customer, dtype: int64

# %% [markdown]
# # g. Which age group spends the most?

# %%
#credit_card.groupby(['Age'])['Amount_y','Amount_x'].sum()
Age_group = credit_card[['Age','Amount_x','Amount_y']].copy()
Age_group['Amount']= Age_group['Amount_x'] + Age_group['Amount_y']
Age_group[['Age','Amount']]
# Out:
#         Age        Amount
# 0      47.0  5.749022e+05
# 1      47.0  3.458901e+05
# 2      47.0  3.489137e+05
# 3      47.0  1.704582e+06
# 4      47.0  5.342872e+05
# ...     ...           ...
# 18785  54.0  1.449884e+05
# 18786  75.0  1.862693e+04
# 18787  29.0  2.549205e+04
# 18788  59.0  2.162744e+05
# 18789  55.0  9.250260e+03
#
# [18790 rows x 2 columns]

# %% [markdown]
# Q2: The demand and usage of the internet is growing across the globe and public wifi is becoming a new normal as we move forward. Wifi providers want to optimize the cost while providing the free and paid wifi. The use case here refers to public WiFi hotspots in New York City. Please refer to the dataset – Wifi Data.xlsx

# %%
df_wifi = pd.read_excel(r'C:\Users\deepak.kapri\Downloads\Data Science boot camp\Wifi Data.xlsx')

# %% [markdown]
# # 1) Get the data provided, check frequency distribution of the features, drop irrelevant and redundant features if any and state your inferences?

# %%
df_wifi.head(10)
# Out:
#    OBJECTID Borough          Type   Provider   Latitude  Longitude Location_T  \
# 0         1      BK  Limited Free  ALTICEUSA  40.658310 -73.944060    Outdoor
# 1         2      BK  Limited Free  ALTICEUSA  40.658000 -73.947230    Outdoor
# 2         3      BK  Limited Free  ALTICEUSA  40.658000 -73.947230    Outdoor
# 3         4      BK  Limited Free  ALTICEUSA  40.657430 -73.947160    Outdoor
# 4         5      BK  Limited Free  ALTICEUSA  40.657430 -73.947160    Outdoor
# 5         6      BX  Limited Free  ALTICEUSA  40.846314 -73.824472    Outdoor
# 6         7      BX  Limited Free  ALTICEUSA  40.847596 -73.822230    Outdoor
# 7         8      BX  Limited Free  ALTICEUSA  40.848159 -73.821071    Outdoor
# 8         9      BX  Limited Free  ALTICEUSA  40.848322 -73.820750    Outdoor
# 9        10      BX  Limited Free  ALTICEUSA  40.849233 -73.821050    Outdoor
#
#        City  BoroCode NTACode
# 0  Brooklyn         3    BK60
# 1  Brooklyn         3    BK60
# ...

# %%
df_wifi.tail(10)
# Out:
#       OBJECTID Borough  Type              Provider   Latitude  Longitude  \
# 2556      2557      MN  Free  LinkNYC - Citybridge  40.764875 -73.980731
# 2557      2558      MN  Free  LinkNYC - Citybridge  40.761640 -73.982996
# 2558      2559      MN  Free  LinkNYC - Citybridge  40.762366 -73.982552
# 2559      2560      MN  Free  LinkNYC - Citybridge  40.763036 -73.981711
# 2560      2561      MN  Free  LinkNYC - Citybridge  40.748482 -73.996012
# 2561      2562      MN  Free  LinkNYC - Citybridge  40.748772 -73.988673
# 2562      2563      MN  Free  LinkNYC - Citybridge  40.750087 -73.987781
# 2563      2564      MN  Free  LinkNYC - Citybridge  40.754951 -73.983899
# 2564      2565      MN  Free  LinkNYC - Citybridge  40.762468 -73.974732
# 2565      2566      MN  Free  LinkNYC - Citybridge  40.775443 -73.982367
#
#          Location_T      City  BoroCode NTACode
# 2556  Outdoor Kiosk  New York         1    MN17
# 2557  Outdoor Kiosk  New York         1    MN17
# ...

# %%
df_wifi.shape
# Out:
# (2566, 10)

# %%
df_wifi.describe()
# Out:
#           OBJECTID     Latitude    Longitude     BoroCode
# count  2566.000000  2566.000000  2566.000000  2566.000000
# mean   1283.500000    40.738396   -73.947564     2.196804
# std     740.884719     0.070845     0.067150     1.282300
# min       1.000000    40.509531   -74.244107     1.000000
# 25%     642.250000    40.693069   -73.985954     1.000000
# 50%    1283.500000    40.743196   -73.958354     2.000000
# 75%    1924.750000    40.796066   -73.922968     3.000000
# max    2566.000000    40.903723   -73.714838     5.000000

# %%
df_wifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2566 entries, 0 to 2565
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2566 non-null   int64
#  1   Borough     2566 non-null   object
#  2   Type        2566 non-null   object
#  3   Provider    2566 non-null   object
#  4   Latitude    2566 non-null   float64
#  5   Longitude   2566 non-null   float64
#  6   Location_T  2566 non-null   object
#  7   City        2566 non-null   object
#  8   BoroCode    2566 non-null   int64
#  9   NTACode     2566 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 200.6+ KB

# %%
df_wifi.keys()
# Out:
# Index(['OBJECTID', 'Borough', 'Type', 'Provider', 'Latitude', 'Longitude',
#        'Location_T', 'City', 'BoroCode', 'NTACode'],
#       dtype='object')

# %%
wifi = df_wifi.drop(['Borough','Latitude','Longitude','BoroCode','NTACode'],axis=1)

# %%
wifi.head()
# Out:
#    OBJECTID          Type   Provider Location_T      City
# 0         1  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 1         2  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 2         3  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 3         4  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 4         5  Limited Free  ALTICEUSA    Outdoor  Brooklyn

# %%
wifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2566 entries, 0 to 2565
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2566 non-null   int64
#  1   Type        2566 non-null   object
#  2   Provider    2566 non-null   object
#  3   Location_T  2566 non-null   object
#  4   City        2566 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 100.4+ KB

# %% [markdown]
# # 2) Using appropriate data visualization answer the following:
#
# a. Plot the providers vs number of all wi-fi hotspots they have in operation? Who has
# the highest installations?

# %%
hotspot_provider = wifi['Provider'].value_counts()
print(hotspot_provider)
# Out:
# LinkNYC - Citybridge       1134
# SPECTRUM                    343
# Transit Wireless            276
# ALTICEUSA                   237
# Harlem                      128
# Downtown Brooklyn           100
# NYPL                         90
# QPL                          65
# BPL                          59
# Manhattan Down Alliance      36
# Chelsea                      30
# NYCHA                        28
# AT&T                         27
# City Tech                    11
# Partner                       2
# Name: Provider, dtype: int64

# %%
sns.histplot(data= wifi, y='Provider',color= 'Green')
plt.show()

# %% [markdown]
# # b. Plot providers vs number of free wifi hotspots.

# %%
free_wifi = wifi[wifi.Type.isin(['Free'])]

# %%
sns.displot(data= free_wifi, y='Provider',hue='Type')
plt.show()

# %% [markdown]
# # c. Are there any provider(s) who do not provide free wifi?

# %%
not_free = ['Limited Free','Partner Site']
not_free_wifi = wifi.loc[wifi['Type'].isin(not_free)]
not_free_wifi
# Out:
#       OBJECTID          Type   Provider Location_T      City
# 0            1  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 1            2  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 2            3  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 3            4  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 4            5  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# ...        ...           ...        ...        ...       ...
# 2519      2520  Limited Free  ALTICEUSA     Indoor  Brooklyn
# 2520      2521  Limited Free  ALTICEUSA     Indoor  Brooklyn
# 2528      2529  Limited Free   SPECTRUM     Indoor  New York
# 2529      2530  Limited Free  ALTICEUSA    Outdoor  Brooklyn
# 2530      2531  Partner Site    Partner    Outdoor  New York
#
# [583 rows x 5 columns]

# %%
not_free_wifi.groupby(['Provider'])['Type'].value_counts()
# Out:
# Provider   Type
# ALTICEUSA  Limited Free    237
# AT&T       Limited Free      1
# Partner    Partner Site      2
# SPECTRUM   Limited Free    343
# Name: Type, dtype: int64

# %% [markdown]
# # d. Which Location type (Location_T) are most common and least common?

# %%
wifi['Location_T'].value_counts()
# Out:
# Outdoor Kiosk         1134
# Outdoor                696
# Subway Station         276
# Library                214
# Indoor                 125
# Outdoor TWC Aerial     121
# Name: Location_T, dtype: int64

# %% [markdown]
# # e. How many free “indoor” and “outdoor” hotspots are there? Which companies have the highest number of Outdoor Free installations.

# %%
wifi['Location_T'].value_counts()
# Out:
# Outdoor Kiosk         1134
# Outdoor                696
# Subway Station         276
# Library                214
# Indoor                 125
# Outdoor TWC Aerial     121
# Name: Location_T, dtype: int64

# %%
outdoor = ['Outdoor Kiosk','Outdoor','Outdoor TWC Aerial']
free =['Free']
outdoor_wifi = wifi.loc[wifi['Location_T'].isin(outdoor)]
outdoor_wifi
# Out:
#       OBJECTID          Type              Provider     Location_T      City
# 0            1  Limited Free             ALTICEUSA        Outdoor  Brooklyn
# 1            2  Limited Free             ALTICEUSA        Outdoor  Brooklyn
# 2            3  Limited Free             ALTICEUSA        Outdoor  Brooklyn
# 3            4  Limited Free             ALTICEUSA        Outdoor  Brooklyn
# 4            5  Limited Free             ALTICEUSA        Outdoor  Brooklyn
# ...        ...           ...                   ...            ...       ...
# 2561      2562          Free  LinkNYC - Citybridge  Outdoor Kiosk  New York
# 2562      2563          Free  LinkNYC - Citybridge  Outdoor Kiosk  New York
# 2563      2564          Free  LinkNYC - Citybridge  Outdoor Kiosk  New York
# 2564      2565          Free  LinkNYC - Citybridge  Outdoor Kiosk  New York
# 2565      2566          Free  LinkNYC - Citybridge  Outdoor Kiosk  New York
#
# [1951 rows x 5 columns]

# %%
outdoor_free = outdoor_wifi.loc[outdoor_wifi['Type'].isin(free)]

# %%
outdoor_free.groupby(['Provider'])['Type'].count()
# Out:
# Provider
# AT&T                         26
# Chelsea                      30
# City Tech                    11
# Downtown Brooklyn           100
# Harlem                      128
# LinkNYC - Citybridge       1134
# Manhattan Down Alliance      36
# NYCHA                        28
# Name: Type, dtype: int64
